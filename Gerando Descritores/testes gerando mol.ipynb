# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from ase.io import read
from dscribe.descriptors import SOAP
import pubchempy as pcp

# %%
path_excel_file = '..\\Bancos de Dados\\qm9.xlsx'
path_mol_files = '..\\Arquivos Mol\\QM9\\'

# %%
df = pd.read_excel(path_excel_file)

# %%
def filtering_database(database, colunas):
    database_copy = database.copy()
    database_copy = database_copy.reindex(columns = colunas)
    padrao = Chem.MolFromSmiles("N")
    padrao2 = Chem.MolFromSmiles("F")
    coluna = "smiles"
    linhas = len(database[coluna])
    progresso = 0
    fracao = 100/linhas
    
    for i in range(linhas):
        progresso = progresso+fracao
        print(f'Progresso: {round(progresso,3)}%', end='\r')
        smile = database[coluna][i]
        mol = Chem.MolFromSmiles(smile)
        #print(mol.HasSubstructMatch(padrao))
        if (mol.HasSubstructMatch(padrao) or mol.HasSubstructMatch(padrao2)): 
            database_copy = database_copy.drop(i)
            
    return database_copy


def getting_canonical_smiles(database):
    database_copy = database.copy()
    coluna = "smiles"
    nova_coluna = "canonical smiles"
    linhas = len(database_copy[coluna])
    fracao = 100/linhas
    progresso = 0 
    
    for i in range(linhas):
        progresso = progresso + fracao
        print(f'Progresso: {round(progresso, 3)}%', end='\r')
        smile = database_copy.loc[i, coluna]
        mol = Chem.MolFromSmiles(smile)
        canonical_smile = Chem.MolToSmiles(mol)
        database_copy.loc[i, coluna] = canonical_smile
    
    database_copy = database_copy.rename(columns={coluna: nova_coluna})
    return database_copy


def chempy_existence(database):
    database_copy = database.copy()
    coluna = "smiles"
    linhas = len(database_copy[coluna])
    fracao = 100/linhas
    progresso = 0 
    for i in range(linhas):
        progresso = progresso + fracao
        print(f'Progresso: {round(progresso,3)}%', end='\r')
        smile = database_copy[coluna][i]
        mol = pcp.get_compounds(smile,"smiles")[0].cid
        if mol == None:
            database_copy = database_copy.drop(i)
            
    return database_copy


def creating_mol_files(database):
    
    coluna = "smiles"
    linhas = len(database[coluna])
    linha = 0
    iteracao = 100/linhas
    for smile in database[coluna]:
        linha = linha + iteracao
        print(f'Progresso: {round(linha,3)}%', end='\r')   
        mol = Chem.MolFromSmiles(smile)
        mol = Chem.AddHs(mol)
        AllChem.EmbedMolecule(mol)
        Chem.MolToMolFile(mol,f"{path_mol_files}{smile}.mol")

# %%
colunas = ["mol_id", "smiles","h298"]
database_filtrado = filtering_database(df,colunas)
database_filtrado.to_pickle("qm9_filtrada.pickle")

# %%
df_filtrada = pd.read_pickle("qm9_filtrada.pickle")
# Out:
#            mol_id               smiles        h298
# 0           gdb_1                    C  -40.475117
# 1           gdb_3                    O  -76.400922
# 2           gdb_4                  C#C  -77.304583
# 3           gdb_6                  C=O -114.479802
# 4           gdb_7                   CC  -79.759722
# ...           ...                  ...         ...
# 50673  gdb_133870    C1C2C3CC4OC2C13O4 -421.735001
# 50674  gdb_133871    C1C2C3OC4CC13C2O4 -421.748195
# 50675  gdb_133875  C1C2C3C2C2C4OC12C34 -384.590076
# 50676  gdb_133877  C1C2C3C4C5CC13C2C45 -348.690357
# 50677  gdb_133880  C1C2C3C4C5OC13C2C45 -384.603362
#
# [50678 rows x 3 columns]

# %%
df_filtrada_smile_canonico
# Out:
# Progresso: 100.0%%

# %%
soap = SOAP(
    species=['H', 'C', 'O'],
    rbf="gto", 
    r_cut= 6, 
    n_max= 1, 
    l_max= 0, 
    sparse=False
)


def creating_soaps(database, path, method):
    coluna = "smiles"
    lista_de_soaps = []
    iteracao = 100/len(database[coluna])
    linha = 0
    for smile in database[coluna]:
        linha = linha + iteracao
        print(f'Progresso: {round(linha,3)}%', end='\r')   
        mol_file = path+f"{smile}.mol"
        mol = soap.create(read(mol_file))
        mol = sum(mol)
        lista_de_soaps.append(mol)
        
    return lista_de_soaps

# %%
soaps_sum = creating_soaps(df_filtrada,path_mol_files,"a")
# Out:
# Progresso: 100.0%%

# %%
chempy_existence(df_filtrada)
# Out:
# Progresso: 0.357%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 chempy_existence(df_filtrada)
#
# Cell In[173], line 53, in chempy_existence(database)
#      51 print(f'Progresso: {round(progresso,3)}%', end='\r')
#      52 smile = database_copy[coluna][i]
# ---> 53 mol = pcp.get_compounds(smile,"smiles")[0].cid
#      54 if mol == None:
#      55     database_copy = database_copy.drop(i)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pubchempy.py:321, in get_compounds(identifier, namespace, searchtype, as_dataframe, **kwargs)
#     312 def get_compounds(identifier, namespace='cid', searchtype=None, as_dataframe=False, **kwargs):
#     313     """Retrieve the specified compound records from PubChem.
#     314
#     315     :param identifier: The compound identifier to use as a search query.
#    (...)
#     319                          :class:`~pandas.DataFrame` and return that.
#     320     """
# --> 321     results = get_json(identifier, namespace, searchtype=searchtype, **kwargs)
#     322     compounds = [Compound(r) for r in results['PC_Compounds']] if results else []
#     323     if as_dataframe:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pubchempy.py:299, in get_json(identifier, namespace, domain, operation, searchtype, **kwargs)
#     297 """Request wrapper that automatically parses JSON response and supresses NotFoundError."""
#     298 try:
# --> 299     return json.loads(get(identifier, namespace, domain, operation, 'JSON', searchtype, **kwargs).decode())
#     300 except NotFoundError as e:
#     301     log.info(e)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pubchempy.py:292, in get(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     290             response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     291 else:
# --> 292     response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     293 return response
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pubchempy.py:271, in request(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     269     log.debug('Request URL: %s', apiurl)
#     270     log.debug('Request data: %s', postdata)
# --> 271     response = urlopen(apiurl, postdata)
#     272     return response
#     273 except HTTPError as e:
#
# File c:\Program Files\Python310\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Program Files\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File c:\Program Files\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File c:\Program Files\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Program Files\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Program Files\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File c:\Program Files\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Program Files\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Program Files\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Program Files\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Program Files\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Program Files\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
smiles_canonicos = getting_canonical_smiles(df_filtrada)
# Out:
# Progresso: 100.0%%

# %%
smiles_canonicos
# Out:
#            mol_id     canonical smiles        h298  \
# 0           gdb_1                    C  -40.475117
# 1           gdb_3                    O  -76.400922
# 2           gdb_4                  C#C  -77.304583
# 3           gdb_6                  C=O -114.479802
# 4           gdb_7                   CC  -79.759722
# ...           ...                  ...         ...
# 50673  gdb_133870  C1C2OC3C4CC3(O2)C14 -421.735001
# 50674  gdb_133871    C1C2OC3C4CC13C4O2 -421.748195
# 50675  gdb_133875  C1C2C3C2C2C4OC12C43 -384.590076
# 50676  gdb_133877  C1C2C3C2C2C4CC12C43 -348.690357
# 50677  gdb_133880  C1C2C3C4C5OC13C2C54 -384.603362
#
#                                                soaps sum
# 0      [100.56466134545224, 37.53798233106532, 0.0, 1...
# 1      [30.531902836068127, 0.0, 18.083297209623076, ...
# 2      [18.59233564365028, 21.660815881383385, 0.0, 3...
# 3      [27.05652741336845, 16.98334077113256, 8.03151...
# 4      [142.68426187070418, 73.51303962197329, 0.0, 3...
# ...                                                  ...
# 50673  [163.39081185056708, 104.85995236610283, 17.54...
# 50674  [124.83605102623108, 98.76470366700215, 16.721...
# 50675  [171.0832450305602, 218.03089998185135, 4.6392...
# 50676  [197.0329675604557, 243.0867830040825, 0.0, 49...
# 50677  [91.81868227616083, 92.61318098951718, 11.0327...
#
# [50678 rows x 4 columns]

# %%
smiles_IPIII = pd.read_pickle('dScribeSOAP_1_0 - QM9.pickle')["Smiles-Canonical"].tolist()
smiles_IPII = smiles_canonicos["canonical smiles"].tolist()

# %%
smiles_IPIII = set(smiles_IPIII)
smiles_IPII = set(smiles_IPII)

# %%
smiles_IPIII - smiles_IPII
# Out:
# set()

# %%
smile = "CC1OC23C=CC(C2)C13"

import pubchempy as pbp

a = pbp.get_compounds(smile, "smiles")[0].cid

# %%
a == None
# Out:
# True

# %%
smiles_IPII - smiles_IPIII
# Out:
# {'CC1OC23C=CC(C2)C13',
#  'COC12CC3CC1C32O',
#  'C#CC12CCC1CC2O',
#  'C#CCC12C3CC1C2O3',
#  'O=CC12CC3CC(O1)C32',
#  'CC1CCC2C3CC12O3',
#  'C1COC2C3CC2(C1)O3',
#  'C#CC12C3CC1C2O3',
#  'COC1CC23CC(O2)C13',
#  'CC1C2OC13CC(=O)C23',
#  'CC1CC23CCC12CO3',
#  'CC12CC1C1(C)OCC21',
#  'C1CC2CC3OCC23C1',
#  'OC1CC2(O)C(O)CC12',
#  'CC1CC2C1OC2(C)C',
#  'OCC12OC1C1CCC12',
#  'OCC1C2OC3C1C23O',
#  'CC1C(C)C2OCC12',
#  'COC1C2C3CC2C31C',
#  'C1=CC2C3CC24C1OC34',
#  'CC12COC1C1CC2O1',
#  'CC1OC2CCC12C',
#  'CC12CCCC3C1CC32',
#  'CC12CC(=O)C1C1OC12',
#  'CC1(O)C2OC3C2OC31',
#  'C1OC1C12OC3C1CC32',
#  'CC1CC2(CO)OCC12',
#  'CC1=CC23OC4C2C1C43',
#  'CCC1C2CC3C1C23C',
#  'CC1C2C3C(C)C2C13',
#  'C1C2CC3C4OC(C14)C23',
#  'O=C1CC2(C1)C1CC2C1',
#  'CC1(O)C2CC3C2CC31',
#  'CC12CC3CC1(CO2)C3',
#  'OC1C2=CCC3C2C13',
#  'CC12CCC1CC21CC1',
#  'CC1CC2CC(C)(O)C12',
#  'CC12OC1C1OCC12O',
#  'O=C1CC2C3CC(C3)C12',
#  'C1OC2CC3(COC23)O1',
#  'C1=CC2C3C1C1CC3C21',
#  'OCC12CC3C(O1)C32',
#  'CC1OC2C(C)C(C)C12',
#  'O=CC1OC23CC(C2)C13',
#  'O=CC1=CC2C3OC2C13',
#  'CC1OC2C3CC3C12O',
#  'CC1C2COC3CC2C31',
#  'OC12CC3(O)C4C(C41)C23',
#  'OC12CC3CCC(C1)C32',
#  'C1CC23OC4CC2C1C43',
#  'CC12COC1C1(CC1)O2',
#  'CC12C(O)C3CC1C32',
#  'CC1C2CC3C1OC23',
#  'C1C2CC3C4OC3(C2)C14',
#  'CCC1OC2CC(C)C12',
#  'OCC1(O)C2C3OC2C31',
#  'C1C2CC3(COC13)C2',
#  'CC12CC3C1C1(CC1)C32',
#  'CC12COC1CC2O',
#  'CC1C2CC3(O)C1C23',
#  'CC1=CC2C3OC2(C)C13',
#  'COC1CC2COC21',
#  'C#CC12CC3(O)C(O1)C23',
#  'CC1OC2CC3CC2C31',
#  'CC1CC2C1C1CC21O',
#  'CC12CC3(CO)OC1C32',
#  'C1OC2C3C1C21OCC31',
#  'CC12OC3CC1C(O)C32',
#  'CCOC12CC3CC1C32',
#  'CC1=CC2(C)C3OC2C13',
#  'OC12CC3(O)C1CC23',
#  'CC1C2OC1(C=O)C2O',
#  'CC1C=C2CC3C1C23O',
#  'CC1(C)C2=CCC3C2C31',
#  'O=C1C(CO)C2OCC12',
#  'CC12C3C4OC3C1(O)C42',
#  'CC12CC3CC1(O)C32O',
#  'CC1OC2COC12C',
#  'CC12CCC13CC(C3)O2',
#  'O1C2C3C2C2C4C1C4C32',
#  'CC12CC3C(O)(C1)C32O',
#  'C#CC12OC3C(O)C1C32',
#  'C#CC12OCC1OC2=O',
#  'COC12CC3C(C1O)C32',
#  'OCC12CC3=CCC1C32',
#  'CC12CC3C4C1C4C32O',
#  'O=C1C2CC13CC(O)C23',
#  'OC12CC34C=CC(C13)C24',
#  'C1=CC23OC4C2OC1C43',
#  'OC1CC2(C1)C1CC2C1',
#  'CCC1C2C3OC2(C)C13',
#  'C1OCC2C3CC2(C3)O1',
#  'CC1C2OC3C(C)C1C23',
#  'O=CC12CC3C1C(O)C32',
#  'OCC1C2=CCC3C2C13',
#  'OCCC1C2C3CC2C13',
#  'CC12CCC1C(=O)C2O',
#  'CCC12OC3C1CCC32',
#  'C1=CC23CCC2C1O3',
#  'C1=CC2C3C=CC2(C1)O3',
#  'CC1C2OC3C(O)C2C13',
#  'CC1C2CC3CC2(O)C31',
#  'OCCC12CC3CC1C32',
#  'C1OCC23COC2C1O3',
#  'CC(O)C12OC3C1OC32',
#  'O=CC1C(=O)C2CCC12',
#  'CC12C3CC1C1(O)C3C21',
#  'C1=CC2CC3CC(C1)C23',
#  'C1OC23CCC2C2C1C23',
#  'CC1C2CC3C1C23C=O',
#  'O=CC12C3CC1CC2C3',
#  'CC1CC2OC3C1CC23',
#  'CC1COC2C3OC2C13',
#  'CC1CC2CC13COC23',
#  'CC1C2C3C(O)C2C13O',
#  'C1C2OC3C1C1OC1C23',
#  'CC1C2CC3OCC31C2',
#  'OC12C=CC3C(C1)OC32',
#  'CC1CC2COC12C',
#  'CC12CC(O)C1CC2O',
#  'C1=CC23C=CC4C2C1C43',
#  'C1C2OC34CCC23OC14',
#  'O=C1CC2CC3CCC132',
#  'O=C1OC2C3C=CC12C3',
#  'CC1C2C3OC2(C)C13',
#  'CC1CC2(C)OC(C)C12',
#  'C#CC12CC3C1CC32O',
#  'O=CC12C(O)C3OC1C32',
#  'C1CC23C4CC2(C4)OC13',
#  'CC12OC(C1O)C21CC1',
#  'O=C1OC2C3C4CC13C42',
#  'CC12C3CC1C2(C=O)O3',
#  'OC12C3CC1CC2C3',
#  'CC12C3CC4C3C1(C)C42',
#  'CC12C3C4CC3C1C42',
#  'OCC12CC1C1OCC12',
#  'CCOC1C2OC3C1C23',
#  'CC12CC3(C)C1CC23',
#  'OC1C2COC3CC1C32',
#  'OCC1(O)C2CC3C2C31',
#  'C1CC23CC4CC12OC43',
#  'CC1C2CC13CC(=O)C23',
#  'C1C2C3OC4OC3C1C42',
#  'CC12OCC1OC2CO',
#  'CC12OC3C(C1O)C32O',
#  'O=C1C2CC3(CO)C1C23',
#  'O=C1C2CC3C1C23O',
#  'COC1C2OC3C2C13C',
#  'O=C1CC23CC(CO2)C13',
#  'CC1C2CC3(CCC13)C2',
#  'CC12C3CC4C3C1C42',
#  'O=CC1CC2C(O)CC12',
#  'CC1(C)CC2CCC21C',
#  'CC12CC3OC1C3(C)O2',
#  'OC12CCC1OC21CC1',
#  'OC1C2OC3C1C(O)C23',
#  'CC12OCC1C1CCC12',
#  'C#CC1CC2C(=O)CC12',
#  'C#CC12OC3C1CC32',
#  'CCC12C3CC1C1C3C12',
#  'C1OC23CC(C4CC42)C13',
#  'CC1COC2C3CC12C3',
#  'OC12CC3CC1(O)C3C2',
#  'C1CC23C1C1C4C(C42)C13',
#  'O=C1CC2C3CC1C2O3',
#  'C#CC1OC2C(=O)OC12',
#  'O=CC12CCC1C1OC12',
#  'OC1CC2CCC12O',
#  'COC1CC2(O)CCC12',
#  'C#CC12OC1C1CCC12',
#  'CC1OC2CCC12',
#  'CC1C(=O)C2(C)CCC12',
#  'C1OC2CC3C4CC23C14',
#  'CCC12CC3C1CC32',
#  'C1OC2COC12',
#  'CC1CC23CC(O2)C3O1',
#  'OCC12OC3C1COC32',
#  'CC1(C)C2CC3OC2C31',
#  'CC12C3C=CC14OC2C34',
#  'C#CC12CC3CC1C32',
#  'CC1C(=O)C2COC12',
#  'OC12COCC3C1OC32',
#  'COC12C3OC4C3C1C42',
#  'C1CC23CC4CC12CC43',
#  'CC12C=CC3CC1C3C2',
#  'CC1C2C3CC1(CO)C32',
#  'CC1OC2CC3OC1C23',
#  'O=C1CC2CC3OC1C23',
#  'C1OCC23CCC2C1O3',
#  'C1CC2OC3CCC1=C23',
#  'OC12CC3OCC1C3C2',
#  'CCC1C2C3OC2C13',
#  'CC12OC3C(C1CO)C32',
#  'CC1CC2CC(C)C12C',
#  'O=CC12CCC1C(=O)O2',
#  'O=CC1C2C(=O)C3C1C23',
#  'CC1OC2C3CCC12C3',
#  'CC1C2C=CC3OC2C31',
#  'CC12CCC1(O)CC2=O',
#  'OC12CC3OC1CC32O',
#  'C1=CC23COCC2C1O3',
#  'CC12OC1C1CCC12',
#  'O=CC12OCC1CC2=O',
#  'COC12C(=O)C3OC1C32',
#  'CC1C2CC3OC2C31O',
#  'OC1CC23CC(CO2)C13',
#  'O=C1C2CC3(COC13)C2',
#  'CC1(C)CC2COC21C',
#  'O=C1CC2(O)CC(O)C12',
#  'C1=CC23CC1C2OCO3',
#  'C1CC23CCC2(C1)CC3',
#  'C1C2OCC23COC13',
#  'C1C2OC3C1C2C31CO1',
#  'CC12CC3OCC1OC32',
#  'CC1OC23COC2CC13',
#  'O=C1C2CC3C1C(O)C23',
#  'CC12CC3C(C1)C32',
#  'CC1C2C3CC2C13',
#  'CC12CCC1C1(CC1)C2',
#  'CC12CCC1CC2=O',
#  'OC1C2OC3CC2(O)C31',
#  'CC12CC3OC1(C=O)C32',
#  'CC12CC(O)C1CC2=O',
#  'OC1CC2C1CC21CO1',
#  'C1=CC2C(C1)C1OCC21',
#  'O=C1OC2CC3OCC132',
#  'C1=CC23CCCC2C1O3',
#  'O=C1CC23CCC12CC3',
#  'O=C1OC2(CO)COC12',
#  'CC1C2CC3C2COC13',
#  'CC12CC3C(C1)C32CO',
#  'C1OC23CC(C2)C2C1C23',
#  'C1CC2C3OC2C3CO1',
#  'O=C1CC2CC(O)C12O',
#  'OC1C2CC3(O)CC2C13',
#  'CC12COC1C(CO)O2',
#  'CC12CC3CC(C)(O1)C32',
#  'C1C2OC3C4OC1C4C23',
#  'CCC12OC3CC1(O)C32',
#  'C1=CC23C=CC(O2)C3C1',
#  'CC1(O)C2CC3C2OC31',
#  'OCC1C2C3OC2C13O',
#  'CC1OC2CC3CC12O3',
#  'COC1CC12C1CC2C1',
#  'CC12CC3CC1(O)C32C',
#  'C#CC1C2OC3C1C23O',
#  'C#CC12CCC1OC2',
#  'CC12OC3C1C(O)C32',
#  'CC1C2CC13CCCC23',
#  'OC12CCOC3C1OC32',
#  'O=C1CC23OC4C2C1C43',
#  'OC1C2C3OCC3C12O',
#  'OC12CC3OC1CC32',
#  'O=C1CC2C1C1C(O)C21',
#  'C1CC23COC1C2CO3',
#  'CC1C2C(C)C3(O)C1C23',
#  'OC1C2COC13COC23',
#  'O=CC1OC2C3CC3C12',
#  'C#CC12C3CC4C3C1C42',
#  'O=C1C(O)C2OCC12',
#  'C#CC12CC3OC1(C)C32',
#  'OC1C2C=CC13COC23',
#  'CCC12CCC1CO2',
#  'CC1C2CC3(C)OC2C13',
#  'CC12C3OC1C1C3OC12',
#  'CC1(O)C2=CCC3C2C31',
#  'CC1C(=O)C2(C)OCC12',
#  'C1CC23OC4C2CC43O1',
#  'C#CC1CC2OCC12C',
#  'OC12CC3CCC1OC32',
#  'CC#CC12OC3C1OC32',
#  'OC1CC2C1C1C(O)C21',
#  'CC1C2OC1C21CC1',
#  'C1CC23CC(C2)OC13',
#  'O=C1C2CC3C1C23',
#  'CC12CC1C1C(=O)OC12',
#  'C1CC2(O1)C1C3CC1C32',
#  'CC12CC3(C1)OC(=O)C23',
#  'CC1C(=O)C2C3CC12C3',
#  'CC1OC2C3COC3C12',
#  'C1CC23CC4OC2CC143',
#  'C#CC12C3CC1C2(C)O3',
#  'CC12CC3C=CC1CC32',
#  'CC12CC3OC1CC32C',
#  'CCC12C3OC1C1C3C12',
#  'CC12C(CO)C3CC1C32',
#  'O=C1CC2C3OC3C12',
#  'CC12COC1C1CC12',
#  'COC12C3CC1C2(O)C3',
#  'CC12CC(C)(O1)C21CC1',
#  'CCC1(C)CC2CCC21',
#  'OC1C2CC3COC31C2',
#  'CCCC12OC3CC1C32',
#  'CC12CC3CC(CO1)C32',
#  'OC12CC3CC(C1)C32',
#  'OCC12CC3CC1OC32',
#  'CC12CCC1(C=O)OC2',
#  'OC1CC2(O)C3OC3C12',
#  'CCC1CC2C3CC3C12',
#  'CC12CC3C1C3(CO)O2',
#  'CC1C2OC13COCC23',
#  'CC1OC2(C)C(O)CC12',
#  'OC12C3CC4C=C3C1C42',
#  'C1OC2C3OC24C1CC34',
#  'CC1CC2OC13COC23',
#  'CC1C2C3CC1(O)C32O',
#  'C1CC2C1C1COCC21',
#  'C1OC23CC4C2C1C43',
#  'OC1CC2C1C1CC21O',
#  'O=C1CC2OC3CC1C23',
#  'CC12C3CC1C1OC3C12',
#  'C1CC2(CC3CCC32)O1',
#  'OC12CCCC13CC2O3',
#  'C1OC23CC4(COC42)C13',
#  'OC12CC3C4C(CC41)C32',
#  'C#CC1OC2C3OC3C12',
#  'O=C1OC2C3CCC12C3',
#  'CC12CC3CC(C1)C32O',
#  'C1=CC23CCC1C2OC3',
#  'C1CC23OC4(CCC24)C13',
#  'C1CC2C3CC24C1OC34',
#  'CC1(C)C2OC1C21CO1',
#  'OC1C2=CCC3CC1C23',
#  'C1OC23COC2CC1C3',
#  'CCC1CC12C1CC2C1',
#  'C1CC2C3CC4C1C2C43',
#  'OCC12CC3C4C(C31)C42',
#  'C1C2C1C13COC21CO3',
#  'C#CC12C3CC1(O)CC32',
#  'CC12OCC1(O)C1CC12',
#  'CC12CC1(C)C1CCC12',
#  'O=C1C2CC3OC1C32O',
#  'OCC1CC23CC(C2)C13',
#  'O=C1C2CC3OC2C13',
#  'CC1C2CC3(C)CC2C13',
#  'C1C2C3C4C5OC13C2C54',
#  'O=C1C2CCC23CCC13',
#  'CC12CC3=CCC1C32',
#  'OC1C2CC3OCC31C2',
#  'C1OC23CC4C2OC1C43',
#  'CC1CC2CC(O)C12',
#  'CC12CC3(C)C(C1O)C23',
#  'O=C1CC2OC3C1CC23',
#  'CC12CC3CC1(C)C32O',
#  'CC1CC2(CO)CCC12',
#  'CC1OC2C3C4CC13C42',
#  'CC1C(O)C2C(O)CC12',
#  'C#CCC1(C)C2CC1O2',
#  'C1OCC23OCC2OC13',
#  'CC1C2CC3C2CC13C',
#  'O=CC1C2C3C(O)C2C13',
#  'C1C2C3C1C1(CO1)C23',
#  'CC12C3CC1C1(CC1)C32',
#  'CCC12CC3=CCC1C32',
#  'CC12C(=O)OC1CC2O',
#  'CC1OC2C3OC3C12O',
#  'C1C2CC34CC(C3)C1C24',
#  'OC12CC1(O)C1OCC12',
#  'O=C1CC2(O)C(O)CC12',
#  'O=C1CC2C3OC2C13O',
#  'CC1C=C2CC3(O)C2C13',
#  'CC1(C)C2CC3CC1C32',
#  'C1CC2C3CC2(C3)O1',
#  'CC12OC3C1C1(CC1)C32',
#  'O=C1C2CCC13CCC23',
#  'CC12OCC1(O)CC2=O',
#  'C#CC1(O)C2C3CC2C31',
#  'C1CC1C1CC2COC21',
#  'O=CCC12CC3OC1C32',
#  'O=C1CC2(O)COC12',
#  'O=C1C2CC3(CCC13)C2',
#  'C1CC23CCC2(CO3)O1',
#  'O=CC12C3CC1C1C3C12',
#  'OC1C2CCC23OCC13',
#  'OC1C2OC1C21CC1O',
#  'OCC12CC3CC1(O)C32',
#  'C1CC2C3C4OC3C24C1',
#  'C1CC2C3C(O1)C1C2C31',
#  'OC12CC3OC1C=CC32',
#  'CC12CC3C1CC(O)C32',
#  'OC12C3=CC4=CC3C1C42',
#  'C1CC1C1CC2OCC21',
#  'C#CC12C3OC1C1C3C12',
#  'O=C1OCC12C1CC2O1',
#  'CC1CCC23CC(C2)C13',
#  'CC12C3C(=O)C1C1C3C12',
#  'C1CC23COCC12CO3',
#  'O=C1OC23CC4C2CC143',
#  'CC12OC3CC1C32C',
#  'CC1C2C=CC13COC23',
#  'CC1C2CC3OC2C31C',
#  'COC1OC2C3OC2C13',
#  'CC1OC2CC13OCC23',
#  'CC12CC3CC1C32C',
#  'C#CC12OC(C1C)C2C',
#  'CC12COC1C(C=O)C2',
#  'COC1C2OC3C2C13O',
#  'C1=C2CC3OCC23CC1',
#  'OC12CC3OCC3(C1)C2',
#  'CC1OC2CC13CCC23',
#  'CC1C2CC3(O)CC1C23',
#  'CC12CC3(C=O)OC1C32',
#  'CC1C2CC3C(O)C1C23',
#  'C1CC12OC1C3OC3C12',
#  'CC1CC2C3CC3(C)C12',
#  'CC12CC3(C)C(CC13)O2',
#  'O=C1CC2CC3(CC3)C12',
#  'C1=C2C(OC1)C1COC21',
#  'O=CCC12OC3CC1C32',
#  'C1CC23CC4C2OC1C43',
#  'OC1CC23COC2CC13',
#  'C#CC12CCC1C(=O)O2',
#  'C1=CC2C3OC2C3OC1',
#  'C1OC2C3OC4C2C1C34',
#  'OC1C2CC3(CCC13)C2',
#  'CC1OC12C1C3CC1C32',
#  'C1=C2C3C4OC3C24OC1',
#  'O=C1OC23CC(C2)C13',
#  'CC(O)C12OC3CC1C32',
#  'OC12CC(C1)C1OCC12',
#  'CC1C2C3C1C(C)(C)C23',
#  'CC1C2CC3(C)OC1C23',
#  'O=C1C2CC3C1C23CO',
#  'C1CC23C1OC1C2OC13',
#  'CC1CC2C(=O)C(O)C12',
#  'CC1(O)C2OC3C2C31',
#  'CC1C2C(O)C3(O)C1C23',
#  'C1=CC23CCC2C2C1C23',
#  'CC12CC3OC1C32C=O',
#  'COC12C3CC1(O)CC32',
#  'CC12CC3(C1)OCOC23',
#  'COC12C(=O)C3CC1C32',
#  'O=C1C2OC3C1C23CO',
#  'CC12CC3OCC1C3C2',
#  'CC12OC3C1C=CCC32',
#  'O=C1C2CC3(C2)OCC13',
#  'OC12C=CC3C(CC31)C2',
#  'OC1C2OC13CCOC23',
#  'OC12COC13C=CC2C3',
#  'C#CC1C2C3OC1(C)C32',
#  'O=C1CC2CC(O)C12',
#  'CC1OC2CC(O)C12',
#  'CCC1OC2CCC12C',
#  'CC1CCC2C3CC2C13',
#  'CC1CC2OCC12',
#  'C1OCC2CC3CC1C23',
#  'OC12C3OC4C3C1C42',
#  'CC12OC3CC1(O)C32C',
#  'C1OC23C1CC21CC3O1',
#  'CC12OC(C1O)C2C=O',
#  'CC(C)C12CC3OC1C32',
#  'OC12C=CCC3C1OC32',
#  'O=C1OC2CC13OCC23',
#  'CC12CC3C1C(CO)C32',
#  'O=C1CC2C3CC2(C1)O3',
#  'C#CCC12CCC1CC2',
#  'CC1CC2CC13OCC23',
#  'OCC12CC3(O)CC1C32',
#  'CC12CC3(C=O)C1OC23',
#  'OCCC12CC3C1CC32',
#  'COCC12C3CC1C2C3',
#  'C1C2CC3C4CC3(C2)C14',
#  'CC12CCC1(O)C1OC12',
#  'OCC12CC3C(C1)C32',
#  'CC12OCC13CCC2C3',
#  'CC12CC3(O)CC1(C)C32',
#  'CC12CC3C4C(O1)C4C32',
#  'CCC1CC2OCC12O',
#  'CC1(O)C2C3CC2C31C',
#  'O=C1CC23CC(O2)C13O',
#  'O1C2C3C1C1C2C31',
#  'CC1CC2C3CC(O3)C12',
#  'COC1CC2CC(O)C21',
#  'C1CC23COC24CC3C14',
#  'C#CC12CC3C1CC32C',
#  'O=C1C(CO)C2CCC12',
#  'O=CC1OC2COC12',
#  'CC(C)C1CC2CCC21',
#  'O=C1CC23CC(CC12)C3',
#  'C#CC12COC1C(C)O2',
#  'OC12C3=CC4CC3C1C42',
#  'CC12C3CC1C(O3)C2O',
#  'CC1OC2CC3CC1C32',
#  'O=C1CC2OC3CC12C3',
#  'CC1CC2COC12C=O',
#  'C1OC23C4OC12C1C4C13',
#  'C1OC2CC3(COC3)C12',
#  'O=CC12CC(=O)C1CO2',
#  'OC12CC=C3CC1C32',
#  'CC1CC2C3OC2(C)C13',
#  'CC12CC3C4C1C4C32C',
#  'CCC12OC3C1CC32',
#  'CC1COC12C1CC2C1',
#  'CC1C2C3CCC3C12C',
#  'CC1C(=O)C2C3CC3C12',
#  'C1C2CC1C1OCC21',
#  'CC12CC3C4C1C4(C)C32',
#  'CC1(O)C2OC1C21CC1',
#  'C1=CC2C3C4CC3C24C1',
#  'CC1(O)C2CC3(O)C2C13',
#  'C1OC23COC4C(C12)C43',
#  'COC1CC2COC21C',
#  'CC1OC2CC3CCC312',
#  'CC1=CC2OC3C1CC23',
#  'CC1CC2OC(CO)C12',
#  'CC12CC3(C)C1OC23',
#  'CCC1(C)C2OC3C2C31',
#  'CC12OC3C1CC32',
#  'C1OC2C13CC21COC31',
#  'CC12COC13CC(C3)O2',
#  'CC12C(O)C1C1OCC12',
#  'CCC1OC2C(O)CC12',
#  'CCC12CC3(O)C1OC32',
#  'COC12CC3C(O)C1C32',
#  'OC12CC3C1C1C2C31O',
#  'CC1CC23CCC2C1O3',
#  'OC12CC3C1C3C21CC1',
#  'O=C1C2CC3(O)CC1C23',
#  'OC1C2C=CC13CCC23',
#  'C1CC1C12OC3C1OC32',
#  'C1C2C3C4C5OC4(C12)C53',
#  'O=CC1C2C3CC1(O)C32',
#  'O=C1CC23OCC2CC13',
#  'CC1CC2OC(C)C12C',
#  'CC12CC3OC1C(=O)C32',
#  'OC1CC2CC3C1OC23',
#  'OC12CC3C=CC1CC32',
#  'C1=C2CC3C4OC1C4C23',
#  'CC12OC3C(O)C1C32',
#  'C#CC1CC2CCC12O',
#  'C1C2C1C1C2CC12CO2',
#  'CC12OC3C(CC31)C2O',
#  'CC12C3CC1C(O)C2C3',
#  'CC1C2CC3C(=O)C1C32',
#  'CC1C2C3C1C2C3(C)C',
#  'CC1C(=O)C2COC12C',
#  'C#CC12CC3CC1C32C',
#  'O=CC1(O)CC2CCC21',
#  'C#CC1CC12C1CC2O1',
#  'CCC12OCC1CC2C',
#  'CC#CC12CC3OC1C32',
#  'CCC1C(O)C2OCC12',
#  'CC1CC2OC(C)C12',
#  'C1=CC2OC3COC23C1',
#  'C#CC1C2C(O)C3C1C23',
#  'C#CC12OCC1C1CC12',
#  'C1CC23OC4C2OC43C1',
#  'O=C1C2OC3C1C(O)C23',
#  'CC12CC3COC(C1)C32',
#  'CC12COCC3C1OC32',
#  'O=C1C2CC3CC2(O)C13',
#  'CC1C2OC1(C)C2(C)C',
#  'C#CC12C3CC1C2(C)C3',
#  'O1C2C3OC2C13',
#  'CC1CC2C3OC2C3C1',
#  'CCCC1OC2COC12',
#  'CC1=CC2CC3C1CC23',
#  'CC1=C2CC3C(C1=O)C23',
#  'COC1C(C)C2CCC21',
#  'OC1CC23CCC12OC3',
#  'CC12CC3C(=O)C1C32O',
#  'O=C1CC2OCC12',
#  'CC12OC3C1C3C21CO1',
#  'CC12COC13CC(C2)C3',
#  'CC1OC2C3CC2(C3)O1',
#  'CC1C2OCC3OC2C31',
#  'OCC1CC2COC12',
#  'C1=C2C3C4CC3C24OC1',
#  'CCC12CC3C1OC32C',
#  'CC1CC2OCC12C',
#  'OCCC12OC3C1OC32',
#  'CC12OC3C1CC32CO',
#  'OC1C2C3OCC3(O)C12',
#  'C1=CC2OC3C1CC23',
#  'OC1C=C2C3C1C1C2C31',
#  'O=C1C2C3OC1(CO)C32',
#  'CC12OC3C1CCCC32',
#  'OC1CC23OC4C2CC143',
#  'C#CC12CC3CC1C3C2',
#  'C#CC12OCC1CC2O',
#  'OC12COC1C1CCC12',
#  'OCC1C2C3COC3C12',
#  'OC12C=CCC13CC2O3',
#  'CC12CC3C1C3C21CO1',
#  'CC1OC23CCC2C1C3',
#  'CC12CC3(O)C1CC23',
#  'CC12CC3OC1C3(O)C2',
#  'OC12CC34COC(C13)C24',
#  'CC12COC1(C)C(=O)C2',
#  'CC1C2C3C1C2C31CC1',
#  'C#CC12C3CC1(C)C2O3',
#  'C1OC23CC4C(OC42)C13',
#  'OC12CC3OC1COC32',
#  'C1C2C3CC2C32COC12',
#  'CC1OC2C(=O)CC12O',
#  'CC(C)C12CCC1CO2',
#  'O=C1OC2C3CC2C1O3',
#  'C1CC2OC3COC23C1',
#  'C#CC12CC3C1OC32',
#  'CCC12COC1CC2C',
#  'CC12CC3(C)C(O1)C23C',
#  'CC1(O)CC2CC(O)C21',
#  'COCC1CC2COC12',
#  'COC12C3CC1(C)C2O3',
#  'OC1CC2CC3COC132',
#  'CC12C(=O)C3CC1(O)C32',
#  'OC12CC3(O)C1CC23O',
#  'OC12COC1C1CC2O1',
#  'CC12CC3CCC1CC32',
#  'CC1(O)C2OC13COC23',
#  'CCC12CC3CC1(C)C32',
#  'O=C1COC23CC(C2)C13',
#  'CC1=CC2C3OC2C3C1',
#  'O=COC1C2C3OC2C13',
#  'CC1CC2(C)CC(=O)C12',
#  'CC1C2OCC2C12CC2',
#  'CC1C(O)C2(O)CCC12',
#  'C#CC1CC23CC(O2)C13',
#  'CC12COC3CC(C1)C32',
#  'O=CC12CC1C1CCC12',
#  'CC1CC2CC13CCC23',
#  'C1CC23OC4C2OC1C43',
#  'O=C1C2C3CC4C1C2C34',
#  'CCC12CC3OC1C32O',
#  'O=CC1CC2CC(=O)C12',
#  'O=C1C2CCC3OC1C32',
#  'CC1OC23CC4C2CC143',
#  'CC12OCC1CC2CO',
#  'C1OC23CCC24OC3C14',
#  'CC1C2CC3C(C)C2C13',
#  'CC12C3C4CC1(O)C4C32',
#  'O=C1OC2CC3CC12O3',
#  'CC12OCC13CC2CO3',
#  'CC12OC3CC1(CO)C32',
#  'OC12CC3C1C1(CC1)C32',
#  'O=C1C2CC3COC2C13',
#  'CC1CC2C1C1C(C)C21',
#  'CC12CC=CC3C1CC32',
#  'OC1CC2OC3C1OC23',
#  'OC1C=C2CC3OC1C23',
#  'CC1OCC2C3CC12C3',
#  'CC(O)C12OC3C1CC32',
#  'O=C1C2C3C1(O)CC23O',
#  'CC1CC2CC(=O)C12',
#  'OCC1CC12C1CC2C1',
#  'CC1C2C(O)C3CC2C13',
#  'C#CC1(C)C2OC3C2C31',
#  'O=C1C2C(CO)C3C1C23',
#  'CC12CC(O)C1CO2',
#  'CC1CC2C1C1CC21C',
#  'C1C2C3OC4(COC24)C13',
#  'CC1C2CC3(COC13)O2',
#  'C1CC2C3CCC3C2O1',
#  'O=C1C2OCC3OC2C13',
#  'O=CC1CC23CC(C2)C13',
#  'CCC12C(C)C3C1OC32',
#  'CC12CC3(C)C1CC23O',
#  'CC1C2=CC3C4C2C1C34',
#  'CC1(O)C2OC3C1C32C',
#  'O=CC1C2C3OC2C13',
#  'OC1C2C3C4C1C2(O)C34',
#  'CC1C(O)C2C(=O)OC12',
#  'O=C1C2C=CC13OCC23',
#  'C1=C2CC3C2C2C1C32',
#  'OC12CCC1C1(O)CC21',
#  'C1C2C1C1C2CC12CC2',
#  'OCC1(CO)C2CC1O2',
#  'C1C2OC3C4OC13C4O2',
#  'OC1CCC2C3OC2C13',
#  'CC12C3C=CC14CC2C34',
#  'C1C2C3OCC34C1OC24',
#  'CC12C3=CC4=CC3C1C42',
#  'OCC12COC1CC2O',
#  'C1OCC2C3OC2C13',
#  'COC1C2C3C(C)C2C13',
#  'C1C2OC3C1C1OC3C21',
#  'CC12COC1C1C(O)C12',
#  'CC12CCC13CC2CO3',
#  'CC1C2C3C(O)C2C13',
#  'C#CC12C3CC1CC2C3',
#  'OC12C3CC1C1C3C12',
#  'OC12C3OC1C3C21CO1',
#  'CC12C3CC1C3C21CO1',
#  'CC1C(C)C2C(=O)OC12',
#  'CC(=O)C12CCC1CO2',
#  'CC1C2C(=O)C1C21CC1',
#  'CC12OC3(C)C1CC23O',
#  'C1C2CC34CCC23CC14',
#  'O=CC12C(=O)C3CC1C32',
#  'CC1=CC23CC(C2)C3C1',
#  'O=CC1C2C3CC2(O)C13',
#  'OCC1C2CC1(CO)C2',
#  'OC1CC2(O)COC12',
#  'O=C1CC2C3OCC3C12',
#  'CCC12CC3C(C1)C32O',
#  'C#CC1OC2C3OC2C13',
#  'CC12CC3OC(C1)C32O',
#  'CC1C2OC3CC2(O)C31',
#  'C1OC2C3CC24C1CC34',
#  'OC1C2CC3CC2(O)C31',
#  'C1=CC23CCC2C1OC3',
#  'C1CC1C1OC2CCC21',
#  'CC1C2C3CC1(C)C32',
#  'O=C1CC2C3CC12CO3',
#  'CC12COC3C1CC32C',
#  'OC1CC2OCC12',
#  'CC12OC3C1COCC32',
#  'C1=CC23COC(C2)C3C1',
#  'OCC12C3CC1C2C3',
#  'C1CC23COC2C(C3)O1',
#  'C1=CC23CC4OC2C1C43',
#  'CC12CC(C)(C1)C21CC1',
#  'C1OC2C3C4OC13C24',
#  'CC12CC(O)(C1)C21CO1',
#  'CC(=O)C1C2OC3C2C31',
#  'O=C1C2C3OC4C1C2C34',
#  'CC1C(=O)C23CC(O2)C13',
#  'CC12C3CC1C1C3C12O',
#  'CC1CC23C=CC(O2)C13',
#  'C#CC1OC2CC(=O)C12',
#  'CC1(O)C2CC13OCC23',
#  'C1CC23CC(C2)C3CO1',
#  'O=C1OC2C1CC21CC1',
#  'O=CC1OC2C(=O)CC12',
#  'CC1(O)C2CC3(C)C2C13',
#  'O=C1CC2OC3CCC132',
#  'CC12OCC1OC2=O',
#  'C1CC23C1CC21CC3C1',
#  'CC12C(O)C3C1CC32',
#  'CC1(O)CC2OCC21',
#  'CC1C2OC3(C)C2C13O',
#  'C1=CC2OC3CC(C1)C23',
#  'CC1C(O)C23CC(O2)C13',
#  'C1CC23CC4(OCC24)C13',
#  'CC1C2OC3C(O)C1C23',
#  'C#CC12OC3C(C1C)C32',
#  'O=CC12C3CC1(O)C2O3',
#  'CC12CCC3OC1C3C2',
#  'CC12CC(O)C1C(O)C2',
#  'C1=CCC2C3OC2C3C1',
#  'CC(C)C12OC3C1OC32',
#  'C#CC12CCC1CO2',
#  'C1CC2C3CC24C1CC34',
#  'C1CC1C12CC3C1CC32',
#  'CC1C2CC3CC2C31O',
#  'C1C2C1C1OC3C2CC13',
#  'O=C1OC2C1C1CC12O',
#  'C1C2CC34OCC23OC14',
#  'CC1OC2CCC12O',
#  'CC12CC3C(O)C1(C)C32',
#  'O=C1C2OC3CC2(O)C13',
#  'CC1C2CC3(C)C1CC23',
#  'C1=CC2CC3C(C1)OC23',
#  'C1C2OC3C4CC3C4C12',
#  'C1CC23CC4OC(C12)C43',
#  'C1C2CC34CC(C13)C4O2',
#  'C1CC1C12C3CC1C2O3',
#  'CC12OCC13C=CC2O3',
#  'CC1C2CC3CC1(C)C32',
#  'COC1C(C)C2OCC12',
#  'CC1(C)C2C3C(O)C2C31',
#  'C1CC23OC4CC12OC43',
#  'CC12C3C(O)C4C3C1C42',
#  'CC12CCC34CC(C13)C24',
#  'CC12CC3C1CC3(O)C2',
#  'CC1CC2C3CC2(C3)O1',
#  'OCC12OC3C1OC32',
#  'OC12CC=CC3C1CC32',
#  'CC1(O)C2CC13CCC23',
#  'C1OC2C3OC24C1OC34',
#  'O=C1C(O)C2OCC12O',
#  'C1CC2COC23CC1C3',
#  'C#CC12C3CC1C2(O)C3',
#  'CC12C(=O)C3C(C1O)C32',
#  'OCC12CC3C(CC31)O2',
#  'CC12C3OC1C1C3C12',
#  'O=C1C2C(O)C3C1C23',
#  'CC12OC3CC4C(C31)C42',
#  'O=C1C2CC3(O)C1CC23',
#  'CC1C2(C)C3CC2C13C',
#  'CC1(O)C2CC3C1C32C',
#  'CC1CC2(C)C(C)CC12',
#  'CC1OC23COC2C1C3',
#  'C1=CC23CC(C1)C2CO3',
#  'CC1C2=CCC3C1C23O',
#  'CC1OC12C1CC3C1C32',
#  'CC12CC(=O)C3C1OC32',
#  'CC1(O)C2CC3C1C32O',
#  'CC12CC3=CCC(C1)C32',
#  'CC12CC3OC1(C)C32',
#  'CC12OCC1C1OCC12',
#  'C1C2OC1C21CC1',
#  'C1OCC23CC(C2)OC13',
#  'C1CC2C(C1)C1OCC21',
#  'COC1C(=O)C2OCC12',
#  'C1OC2C3OC2C3O1',
#  'C1=C2C3C4C1C1C2C3C41',
#  'C1CC2(C1)CC1OCC12',
#  'OC12CCC13CCC3C2',
#  'C1OC2CC3OCC1=C23',
#  'CC1CC2(O)C(C)CC12',
#  'CC12CC3CC1(C)C3C2',
#  'CC1C2C3C(=O)C2(C)C13',
#  'CC1CC2(O)C(O)CC12',
#  'CCC12OC3C1C(C)C32',
#  'CC12OC3C1OC32C=O',
#  'C1CC2(C1)OC1COC12',
#  'O=CC1C2C3C(=O)C2C13',
#  'C1CC2C3C1C2C31CC1',
#  'CC1CC2OC3CC1C23',
#  'CC1CC2C1C1C(O)C21',
#  'O=C1C=C2CC3CC1C23',
#  'CC12CC3OC1C3C2=O',
#  'CC1(C=O)CC2COC21',
#  'C1=CC23OC4C2CC1C43',
#  'CC1OC2C(=O)C(C)C12',
#  'C1C2OC3C1C1(CO1)C23',
#  'CC1C2OC3C1C23',
#  'CCC1C2OC3C2C13C',
#  'CC12CC3C(O)C(C1)C32',
#  'CC1=CC2C3C4OC13C24',
#  'OC1CCC2C3CC12O3',
#  'OCC12CC3(O)C(O1)C23',
#  'CCC12COC1CC2=O',
#  'CC1C2C3C4C1C2(C)C34',
#  'CC12CC3CCC(O1)C32',
#  'O=CC12C3CC1(O)CC32',
#  'CC12C(O)C3(O)C1OC23',
#  'CC1OC23CC(CC12)C3',
#  'CC1C2C3C1C1(CC1)C23',
#  'O=C1C2C3CC4C3C1C42',
#  'CC12COCC13CC2C3',
#  'O=C1OC2C3CC3(O)C12',
#  'C1C2CC13CC1OC2C13',
#  'O=C1C(O)C2(O)CCC12',
#  'CC(O)C1C2C3CC2C31',
#  'CC1C2COC3C1OC23',
#  'C#CC12CC3C1OC32C',
#  'CC12CCC13CCC2C3',
#  'COC12CC3CC1OC32',
#  'OC12COC3CC1C3C2',
#  'CC12OC3C4OC(C41)C32',
#  'C1CC23OC4CC2C4C13',
#  'OC1C2C3CC4C3C1C42',
#  'OC12CC3(CCCC13)C2',
#  'C1CC23CCC12CC3',
#  'CC1C2(O)CC3C2C31O',
#  'CC1C2C(=O)C3C1C23C',
#  'CC12CC3C1COCC32',
#  'CC1C2C3CC1(O)C32C',
#  'OC1C2C3C1(O)CC23O',
#  'CC12CC3C(=O)C1C32C',
#  'CC(C)C1C2CC1C2O',
#  'O=CC12C3OC1C1C3C12',
#  'COC1(C)C2OC1C2C',
#  'O=C1OCC2C3CC12C3',
#  'C1OC1C12CC3CC1C32',
#  'C1OC1C12CC3OC1C32',
#  'C1CC2C3CC2(CO1)C3',
#  'CC1C2COC3C1CC23',
#  'COC1C2CC3C2CC31',
#  'CC1OC2C1C1OC21C',
#  'CC12CCC13OCC3O2',
#  'CC12CC3CC1(O)CC32',
#  'OC1C2CCC3CC2C31',
#  'CC12CCC13CCC3O2',
#  'CC12CC3(O)C1OC23C',
#  'OCCC12CC3C(C1)C32',
#  'O=CC12OC3C(C1=O)C32',
#  'CCC1C2C3CC1(O)C32',
#  'CC12C(CO)C3C1CC32',
#  'C1=CC23OC4C2CC43C1',
#  'CC(=O)C1C2C3CC2C31',
#  'CC1OCC12C1CC2C1',
#  'OC12C3OC4CC(C41)C32',
#  'CC12CC3(CCOC13)O2',
#  'O=CCC1C2CC3C1C23',
#  'CC1CC2(O)CCC12',
#  'CC1C(O)C2CC(O)C12',
#  'CC1C2CC3C1C23',
#  'OCC1C2CC3C1C23O',
#  'CC1C2CC3(O)C2C13C',
#  'CC12CC3CC1C32O',
#  'C1CC2C3CCC2(C3)O1',
#  'CC12COC1C1OC12C',
#  'OC1C2CC3(O)C1OC23',
#  'CC12CC1(O)C1OCC12',
#  'CC1C2CCC13OCC23',
#  'O=C1C2CC3(O)C1C23O',
#  'CC12CCC1(C)OC2',
#  'OC1C2C=CC3OC1C32',
#  'CC1C2C(=O)C3C2C13O',
#  'OC12CCC1CC2',
#  'C1OC2CC3C4OC23C14',
#  'C1=C2CC3C4OC3(C1)C24',
#  'O=C1C2CC3C1OCC23',
#  'CCCC12C3CC1C2C3',
#  'CC12CC3CC1COC32',
#  'O=C1CC2C3C=CC12C3',
#  'OC1CCC2C3CC2C13',
#  'CC(C)C12CC3C(O1)C32',
#  'CC12CC3(CC=CC13)O2',
#  'O=C1OC2C3OCC3C12',
#  'CC(=O)C1C2C3OC2C31',
#  'C1C2OC3C4OC3C2C14',
#  'O=CC1CC23CC(O2)C13',
#  'C1CC12C1OC2C12CO2',
#  'C1CC2C3OC4C1C2C43',
#  'C1C2C3C4C5CC4(C12)C53',
#  'CC12OC3C1OC(=O)C32',
#  'CC1C(O)C2C(=O)CC12',
#  'CC12CC3(C=CCC13)C2',
#  'O=CC12CC3CC(C1)C32',
#  'O=C1OC23COC2C1C3',
#  'CC(C)C1C2CC1(C)O2',
#  'O=C1CC2C3CC2(C1)C3',
#  'CC1CC2C3CC12CO3',
#  'CC12CC3CC1C32C=O',
#  'CCC12CC3OC1(C)C32',
#  'CC12COC1CC2=O',
#  'CCC1C2C3C(=O)C2C13',
#  'C#CC1C2CC3C1C23O',
#  'OC12COC3CC1CC32',
#  'C1=C2C3OC4C(C1)C2C34',
#  'CC12OCC3C(CC31)O2',
#  'CC12OC3C1CC32C=O',
#  'CC12OC3C(C1O)C32C',
#  'COC1(C)C2CC1(O)C2',
#  'CC12C3=CCC4C3C1C42',
#  'COC1C2C(O)C3C1C23',
#  'C1CC2OC3C1CC23',
#  'CC(O)C12CCC1OC2',
#  'C1C2OC3C1C2C1OC31',
#  'OC1C2CCC13COC23',
#  'C#CCC12CC3CC1C32',
#  'CC12OC3C1CC(O)C32',
#  'CC12CC3OC1C3C2O',
#  'O=CC12CC3C(C1O)C32',
#  'C1C2CC34COC23C1C4',
#  'C#CC12CC(O1)C21CC1',
#  'COC12COC1C1OC12',
#  'CC1(O)C2CC3C2C31',
#  'CC#CC12C3CC1C2O3',
#  'CCC12CCC1CC2C',
#  'CC12OC3C1C=CC32O',
#  'CC1C2CC3C1C23C',
#  'CC(O)C12CC3C(C1)C32',
#  'CC1C2CC3C1C(O)C23',
#  'COC12C3OC1C2C3C',
#  'CC1C2CC1(CO)C2O',
#  'OCC1C2C(O)C3C1C23',
#  'CC12CC(O1)C1CCC12',
#  'CC12CC3OC1C32CO',
#  'O=C1OC23CC(C2)OC13',
#  'O=CC12CC3C1OC32',
#  'C1CC2(C3CO3)OCC12',
#  'C1CC2C3CC1C2C3',
#  'CC1CC2OC(=O)C12O',
#  'CC1C2=CCC3OC1C23',
#  'OC1CC2C3CCC3C12',
#  'C1CC23CCC2OC13',
#  'O=C1OC2C(O)CC12',
#  'CC1C2(O)CC3C2C31C',
#  'OCC12C3CC1(O)C2O3',
#  'CC1C2C(=O)C3C2C13C',
#  'CC(O)C12COC1CO2',
#  'O=C1C2OC3CC2C13O',
#  'CC12CCC1(O)CO2',
#  'CCC1CC2(O)COC12',
#  'O=C1CC2C1C1CC21O',
#  'O=COC1CC2COC21',
#  'CCC12CC3C(O)C1C32',
#  'O=CC12C3CC1C2C3O',
#  'OC12CC3C4C1C4(O)C32',
#  'C1C2CC3C1C1CC1C23',
#  'OC12C3CCC14CC2C34',
#  'CC1CC23OC4C2C1C43',
#  'C1OC23C4CC12CC3O4',
#  'C1=C2C3C(C1)C1C2C31',
#  'OC12CC3C1CC3(O)C2',
#  'OC1CC12C1CC3C1C32',
#  'C1C2OC34CC(C3)C4C12',
#  'O=C1C2CC13CCC3O2',
#  'CC12C=CC3OC1C3O2',
#  'OCC12CC(C1)C21CC1',
#  'CC1CC2C3CC2(C1)C3',
#  'OC12CC3C1C=CCC32',
#  'CC1OCC2C3OC2C13',
#  'OC1CC2C3CC1C2C3',
#  'C#CC1(C)OC2CCC21',
#  'O=CC12COC1CO2',
#  'OC12CCC1C1(CC1)C2',
#  'OC1CC2C3CC3C12O',
#  'C#CC12OC3C1C(O)C32',
#  'CC1=C2CC3C2C2C1C32',
#  'C1CC23CCC12CO3',
#  'CC12COC13CCC3C2',
#  'C1=CC23COC2CC1O3',
#  'CC12COC1(C=O)CO2',
#  'CC1C2C3CC1(C)C2O3',
#  ...}

# %%
len(smiles_IPII - smiles_IPIII)
# Out:
# 5437
